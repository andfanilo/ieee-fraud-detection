# %% [markdown]
# # Gues the countries ?

# %% [markdown]
# ## Prerequisites

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import numpy as np
import pandas as pd

from src.dataset.make_dataset import Dataset
from src.visualization.visualize import plot_correlation_matrix

import matplotlib.pyplot as plt
import seaborn as sns

pd.options.display.max_rows = 100
pd.options.display.max_columns = None

# %matplotlib inline

# %%
ds = Dataset()
ds.load_dataset()

# %%
X = ds.X_train.reset_index()
y = ds.y_train.reset_index()['isFraud']
X_test = ds.X_test.reset_index()
X['isFraud'] = y

# %% [markdown]
# * id_14 is supposedly timezone
# * addr2 is supposedly billing country

# %%
temp = pd.crosstab(X['id_14'],  X['addr2']).stack().reset_index().rename(columns={0: "value"})
temp = temp[temp['value']!=0]
temp
# Out:
#       id_14  addr2  value
# 48   -660.0   87.0      2
# 107  -600.0   87.0    498
# 166  -540.0   87.0    111
# 178  -480.0   16.0      1
# 187  -480.0   29.0      1
# 189  -480.0   31.0      1
# 190  -480.0   32.0      4
# 196  -480.0   43.0      3
# 206  -480.0   57.0      2
# 208  -480.0   60.0      3
# 213  -480.0   69.0      1
# 225  -480.0   87.0  12709
# 230  -480.0   96.0     71
# 232  -480.0   98.0      1
# 248  -420.0   31.0      1
# 249  -420.0   32.0      1
# 267  -420.0   60.0      4
# 273  -420.0   70.0      1
# 284  -420.0   87.0   4388
# 288  -420.0   94.0      1
# 289  -420.0   96.0     80
# 299  -360.0   19.0      2
# 305  -360.0   29.0      1
# 306  -360.0   30.0      2
# 326  -360.0   60.0    101
# 333  -360.0   71.0      2
# 340  -360.0   79.0      1
# 343  -360.0   87.0  14681
# 344  -360.0   89.0      1
# 348  -360.0   96.0     29
# 353  -360.0  102.0      5
# 354  -300.0   10.0      3
# 358  -300.0   19.0      4
# 362  -300.0   27.0      1
# ...
