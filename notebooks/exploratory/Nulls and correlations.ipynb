# %% [markdown]
# # Diagnose null values and correlations

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from src.dataset.make_dataset import Dataset
from src.features.build_features import *
from src.model.train_model import *

import impyute as impy
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno

pd.options.display.max_columns = None

# %matplotlib inline

# %%
ds = Dataset()
ds.load_dataset()

# %% [markdown]
# ## Diagnose identity nulls

# %%
ds.X_train[ds.identity_cols].head(15)
# Out:
#                id_01     id_02  id_03  id_04  id_05  id_06  id_07  id_08  \
# TransactionID
# 2987000          NaN       NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2987001          NaN       NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2987002          NaN       NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2987003          NaN       NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2987004          0.0   70787.0    NaN    NaN    NaN    NaN    NaN    NaN
# 2987005          NaN       NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2987006          NaN       NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2987007          NaN       NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2987008         -5.0   98945.0    NaN    NaN    0.0   -5.0    NaN    NaN
# 2987009          NaN       NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2987010         -5.0  191631.0    0.0    0.0    0.0    0.0    NaN    NaN
# 2987011         -5.0  221832.0    NaN    NaN    0.0   -6.0    NaN    NaN
# ...

# %%
msno.bar(ds.X_train[ds.identity_cols], sort='ascending', color=(0.25, 0.45, 0.6))

# %%
msno.heatmap(ds.X_train[ds.identity_cols])

# %% [markdown]
# There are big blocks of nulls present !

# %%
msno.dendrogram(ds.X_train[ds.identity_cols])

# %% [markdown]
# It does seem that some nulls are very correlated

# %%
f, ax = plt.subplots(figsize=(16,12))

# Compute the correlation matrix
corr = ds.X_train[ds.identity_cols].corr()

# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

cmap = sns.diverging_palette(220, 10, as_cmap=True)
sns.heatmap(corr, mask=mask, annot=True, fmt=".2f", cmap=cmap, vmin=-1, vmax=1, center=0, square=True, linewidths=.5, cbar_kws={"shrink": .5}, ax=ax)
f.show()
# Out:
# c:\utilisateurs\a557847\appdata\local\continuum\anaconda3\envs\ieee-fraud-detection\lib\site-packages\ipykernel_launcher.py:12: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   if sys.path[0] == '':

# %% [markdown]
# But those blocks are not visible in classic correlation :/ I guess it may be important to consider those null blocks in FE
