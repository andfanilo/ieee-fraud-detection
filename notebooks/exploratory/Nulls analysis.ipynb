# %% [markdown]
# # Diagnose null values

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from src.dataset.make_dataset import Dataset
from src.features.build_features import *
from src.model.train import *

import impyute as impy
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno

import numpy as np
import pandas as pd

pd.options.display.max_columns = None

# %matplotlib inline

import warnings
warnings.filterwarnings("ignore")

# %%
ds = Dataset()
ds.load_dataset()

# %% [markdown]
# ## Diagnose identity nulls

# %%
ds.X_train[ds.identity_cols].head(15)
# Out:
#                id_01     id_02  id_03  id_04  id_05  id_06  id_07  id_08  \
# TransactionID
# 2987000          NaN       NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2987001          NaN       NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2987002          NaN       NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2987003          NaN       NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2987004          0.0   70787.0    NaN    NaN    NaN    NaN    NaN    NaN
# 2987005          NaN       NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2987006          NaN       NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2987007          NaN       NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2987008         -5.0   98945.0    NaN    NaN    0.0   -5.0    NaN    NaN
# 2987009          NaN       NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2987010         -5.0  191631.0    0.0    0.0    0.0    0.0    NaN    NaN
# 2987011         -5.0  221832.0    NaN    NaN    0.0   -6.0    NaN    NaN
# ...

# %%
msno.bar(ds.X_train[ds.identity_cols], sort='ascending', color=(0.25, 0.45, 0.6))

# %%
msno.heatmap(ds.X_train[ds.identity_cols])

# %% [markdown]
# There are big blocks of nulls present !

# %%
msno.dendrogram(ds.X_train[ds.identity_cols])

# %% [markdown]
# It does seem that some nulls are very correlated

# %% [markdown]
# ## Diagnose transaction

# %%
msno.bar(ds.X_train[[f'C{i}' for i in range(1, 15)]], sort='ascending', color=(0.25, 0.45, 0.6))

# %%
msno.bar(ds.X_train[[f'D{i}' for i in range(1, 16)]], sort='ascending', color=(0.25, 0.45, 0.6))

# %%
msno.heatmap(ds.X_train[[f'D{i}' for i in range(1, 16)]])

# %%
msno.bar(ds.X_train[[f'V{i}' for i in range(1, 340)]], sort='ascending', color=(0.25, 0.45, 0.6))

# %%
msno.heatmap(ds.X_train[[f'V{i}' for i in range(1, 340)]])

# %%
def find_Vgroups(X, V_variables):
    na_value = X[V_variables].isnull().sum()
    na_list = na_value.unique()
    na_value = na_value.to_dict()
    cols_same_null = []
    for i in range(len(na_list)):
        cols_same_null.append([k for k,v in na_value.items() if v == na_list[i]])
    return cols_same_null
    
V_groups = find_Vgroups(ds.X_train, [i for i in list(ds.X_train) if 'V' in i])

# %%
for ind, c in enumerate(V_groups):
    print(f"Number elements in {ind} is {len(c)}")
# Out:
# Number elements in 0 is 11
# Number elements in 1 is 23
# Number elements in 2 is 18
# Number elements in 3 is 22
# Number elements in 4 is 20
# Number elements in 5 is 43
# Number elements in 6 is 18
# Number elements in 7 is 11
# Number elements in 8 is 31
# Number elements in 9 is 19
# Number elements in 10 is 46
# Number elements in 11 is 16
# Number elements in 12 is 32
# Number elements in 13 is 11
# Number elements in 14 is 18

# %%
for i in range(0, 15):
    msno.heatmap(ds.X_train[V_groups[i]])
