# %% [markdown]
# # Pair plots that look interesting

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from src.utils import printmd
from src.dataset.utils import df_empty
from src.dataset.data import Dataset
from src.features.utils import *
from src.features.build_features import *
from src.visualization.visualize import *
from src.visualization.utils import *

import numpy as np
import pandas as pd

# %matplotlib inline

import warnings
warnings.filterwarnings("ignore")

# %%
sns.palplot(sns.color_palette())

# %%
ds = Dataset()
ds.load_dataset()

# %%
X = ds.X_train.reset_index()
y = ds.y_train.reset_index()['isFraud']
X_test = ds.X_test.reset_index()
X['isFraud'] = y

# %%
plot_joint(X, "C1", "C13").show()

# %%
plot_joint(X, "D1", "D2").show()

# %%
plot_joint(X, "D1", "D2").savefig("../../reports/figures/test.png")
plt.close()
